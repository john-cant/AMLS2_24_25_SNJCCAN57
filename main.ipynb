# %% [markdown]
# <a href="https://colab.research.google.com/github/john-cant/AMLS2_24_25_SNJCCAN57/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
if not os.path.exists('/content/drive/My Drive'):   ## check if Google drive mounted
    from google.colab import drive
    drive.mount('/content/drive')
else:
    print("Google Drive is already mounted.")
# %cd /content/drive/MyDrive/AMLS2
# !python /content/drive/MyDrive/AMLS2/main.py
# Out:
# Google Drive is already mounted.
# /content/drive/MyDrive/AMLS2
# Current directory: /content/drive/MyDrive/AMLS2
# Directory '/content/drive/MyDrive/AMLS2/metrics' already exists.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# ERROR:traitlets:unhandled iopub msg: colab_request
# ERROR:traitlets:unhandled iopub msg: colab_request
# ERROR:traitlets:unhandled iopub msg: colab_request
# ...
